# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
from IPython.display import display_html

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
display_html(df_train.head())
print df_train.describe()
display_html(df_test.head())
print df_test.describe()
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Survived</th>
#       <th>Pclass</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Fare</th>
#       <th>Cabin</th>
#       <th>Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>0</td>
#       <td>3</td>
#       <td>Braund, Mr. Owen Harris</td>
#       <td>male</td>
#       <td>22.0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>A/5 21171</td>
#       <td>7.2500</td>
#       <td>NaN</td>
#       <td>S</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>1</td>
#       <td>1</td>
#       <td>Cumings, Mrs. John Bradley (Florence Briggs Th...</td>
#       <td>female</td>
#       <td>38.0</td>
#       <td>1</td>
#       <td>0</td>
# ...

# %%
df_train[(df_train.Survived==1) & (df_train.Pclass==3) & (df_train.Sex=="male")]
# Out:
#      PassengerId  Survived  Pclass  \
# 36            37         1       3
# 65            66         1       3
# 74            75         1       3
# 81            82         1       3
# 107          108         1       3
# 125          126         1       3
# 127          128         1       3
# 146          147         1       3
# 165          166         1       3
# 204          205         1       3
# 207          208         1       3
# 220          221         1       3
# 261          262         1       3
# 267          268         1       3
# 271          272         1       3
# 283          284         1       3
# 286          287         1       3
# 301          302         1       3
# 338          339         1       3
# 348          349         1       3
# 391          392         1       3
# 400          401         1       3
# 414          415         1       3
# 429          430         1       3
# 444          445         1       3
# ...

# %%
temp=df_train[df_train.Age > 0][["Pclass", "Sex", "Survived"]].groupby(['Pclass', 'Sex']).agg(['count','sum'])
temp['Percent'] = temp['Survived']['sum']/temp['Survived']['count']*100
temp
# Out:
#               Survived        Percent
#                  count sum
# Pclass Sex
# 1      female       85  82  96.470588
#        male        101  40  39.603960
# 2      female       74  68  91.891892
#        male         99  15  15.151515
# 3      female      102  47  46.078431
#        male        253  38  15.019763

# %%
temp['Percent'] = temp['Survived']['sum']/temp['Survived']['count']

# %%
temp
# Out:
#               Survived       Percent
#                  count sum
# Pclass Sex
# 1      female       94  91  0.968085
#        male        122  45  0.368852
# 2      female       76  70  0.921053
#        male        108  17  0.157407
# 3      female      144  72  0.500000
#        male        347  47  0.135447

# %%
df_temp = df_train.loc[:,['PassengerId','Sex','Survived']]
df_temp['Predict'] = df_temp.Sex.apply(lambda x: 0 if x=="male" else 1)
df_temp['Correct'] = (df_temp.Predict == df_temp.Survived)
df_temp
# Out:
#      PassengerId     Sex  Survived  Predict Correct
# 0              1    male         0        0    True
# 1              2  female         1        1    True
# 2              3  female         1        1    True
# 3              4  female         1        1    True
# 4              5    male         0        0    True
# 5              6    male         0        0    True
# 6              7    male         0        0    True
# 7              8    male         0        0    True
# 8              9  female         1        1    True
# 9             10  female         1        1    True
# 10            11  female         1        1    True
# 11            12  female         1        1    True
# 12            13    male         0        0    True
# 13            14    male         0        0    True
# 14            15  female         0        1   False
# 15            16  female         1        1    True
# 16            17    male         0        0    True
# ...

# %%
df_temp.Correct.sum()*100.0/df_temp.Correct.count()
# Out:
# 78.675645342312009
